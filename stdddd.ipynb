# %%
import sys

print("stdout 1")
sys.stdout.flush()
print("stderr 1", file=sys.stderr)
sys.stdout.flush()
print("stdout 2")
sys.stdout.flush()
print("stderr 2", file=sys.stderr)
sys.stdout.flush()
# Should preserve chronological order
# Out:
# stdout 1
# stdout 2
# stderr 1
# stderr 2

# %%
# !cat stdddd.ipynb | jq
# Out:
# {
#   "metadata": {
#     "kernelspec": {
#       "display_name": "Python 3",
#       "name": "python3",
#       "language": "python"
#     },
#     "runt": {
#       "schema_version": "1",
#       "env_id": "801d3649-7653-48ea-ba9b-d1e8f5ad7d34",
#       "uv": {
#         "dependencies": []
#       }
#     }
#   },
#   "nbformat": 4,
#   "nbformat_minor": 5,
#   "cells": [
#     {
#       "cell_type": "code",
#       "id": "ad55a0d6-1d94-493f-b4ef-0053484ae7af",
#       "metadata": {},
#       "execution_count": null,
#       "source": [
#         "import sys\n",
#         "\n",
#         "print(\"stdout 1\")\n",
#         "sys.stdout.flush()\n",
#         "print(\"stderr 1\", file=sys.stderr)\n",
#         "sys.stdout.flush()\n",
#         "print(\"stdout 2\")\n",
#         "sys.stdout.flush()\n",
#         "print(\"stderr 2\", file=sys.stderr)\n",
#         "sys.stdout.flush()\n",
#         "# Should preserve chronological order"
#       ],
#       "outputs": []
#     },
#     {
# ...
